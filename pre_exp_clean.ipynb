# %%
import pandas as pd
import numpy as np
from lib_rate import read_freq_gau, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_full_6n, kooji
import matplotlib.pyplot as plt

with open("/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_h20_resume.csv","r") as data:
	df = pd.read_csv(data, delimiter = '\t', index_col=False)

step = 5
t_fin = 300
T = np.arange(0.1, t_fin, step,dtype=float)
q_h2o_cry = np.arange(0.1, t_fin, step,dtype=float)
q_h2o_xtb = np.arange(0.1, t_fin, step,dtype=float)

q_all_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_ads_ref = np.arange(0.1, t_fin, step,dtype=float)

q_frg_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_mol_frg_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_mol_all_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_mol_onl_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)

q_all_cry_des_com = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_des_ref = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_des_ref_opt = np.arange(0.1, t_fin, step,dtype=float)

q_frg_cry_des_com = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_des_ref = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_des_ref_opt = np.arange(0.1, t_fin, step,dtype=float)

f_h2o_cry = pd.Series(df['mol_iso_cry'].to_numpy(dtype=float))
f_h2o_xtb = pd.Series(df['mol_iso_xtb'].to_numpy(dtype=float))

f_all_cry_ads_com = pd.Series(df['cry_ads_all_complex'].to_numpy(dtype=float))
f_all_cry_ads_ref = pd.Series(df['cry_ads_all_ref'].to_numpy(dtype=float))

f_frg_cry_ads_com = pd.Series(df['cry_ads_frag_complex'].to_numpy(dtype=float))
f_frg_cry_ads_ref = pd.Series(df['cry_ads_frag_ref'].to_numpy(dtype=float))

f_mol_frg_cry_ads_com = pd.Series(df['cry_ads_mol_frag_complex'].to_numpy(dtype=float))
f_mol_all_cry_ads_com = pd.Series(df['cry_ads_mol_full_complex'].to_numpy(dtype=float))
f_mol_onl_cry_ads_com = pd.Series(df['cry_ads_mol_only_complex'].to_numpy(dtype=float))

f_all_cry_des_com = pd.Series(df['cry_des_all_complex'].to_numpy(dtype=float))
f_all_cry_des_ref = pd.Series(df['cry_des_all_ref'].to_numpy(dtype=float))
f_all_cry_des_ref_opt = pd.Series(df['cry_des_all_opt_ref'].to_numpy(dtype=float))

f_frg_cry_des_com = pd.Series(df['cry_des_frag_complex'].to_numpy(dtype=float))
f_frg_cry_des_ref = pd.Series(df['cry_des_frag_ref'].to_numpy(dtype=float))
f_frg_cry_des_ref_opt = pd.Series(df['cry_des_frag_opt_ref'].to_numpy(dtype=float))

f_h2o_xtb = f_h2o_xtb[~np.isnan(f_h2o_xtb)]
f_h2o_cry = f_h2o_cry[~np.isnan(f_h2o_cry)]

f_all_cry_ads_com = f_all_cry_ads_com[~np.isnan(f_all_cry_ads_com)]
f_all_cry_ads_ref = f_all_cry_ads_ref[~np.isnan(f_all_cry_ads_ref)]

f_frg_cry_ads_com = f_frg_cry_ads_com[~np.isnan(f_frg_cry_ads_com)]
f_frg_cry_ads_ref = f_frg_cry_ads_ref[~np.isnan(f_frg_cry_ads_ref)]

f_mol_frg_cry_ads_com = f_mol_frg_cry_ads_com[~np.isnan(f_mol_frg_cry_ads_com)]
f_mol_all_cry_ads_com = f_mol_all_cry_ads_com[~np.isnan(f_mol_all_cry_ads_com)]
f_mol_onl_cry_ads_com = f_mol_onl_cry_ads_com[~np.isnan(f_mol_onl_cry_ads_com)]

f_all_cry_des_com = f_all_cry_des_com[~np.isnan(f_all_cry_des_com)]
f_all_cry_des_ref = f_all_cry_des_ref[~np.isnan(f_all_cry_des_ref)]
f_all_cry_des_ref_opt = f_all_cry_des_ref_opt[~np.isnan(f_all_cry_des_ref_opt)]

f_frg_cry_des_com = f_frg_cry_des_com[~np.isnan(f_frg_cry_des_com)]
f_frg_cry_des_ref = f_frg_cry_des_ref[~np.isnan(f_frg_cry_des_ref)]
f_frg_cry_des_ref_opt = f_frg_cry_des_ref_opt[~np.isnan(f_frg_cry_des_ref_opt)]

for i in range(len(T)):
	q_h2o_cry[i] 	 = q_vib(T[i],f_h2o_cry)
	q_all_cry_des_com[i] = q_vib(T[i],f_all_cry_des_com)
	q_all_cry_des_ref[i] = q_vib(T[i],f_all_cry_des_ref)
	q_frg_cry_des_com[i] = q_vib(T[i],f_frg_cry_des_com)
	q_frg_cry_des_ref[i] = q_vib(T[i],f_frg_cry_des_ref)
	q_mol_frg_cry_ads_com[i] = q_vib(T[i],f_mol_frg_cry_ads_com)
	q_mol_all_cry_ads_com[i] = q_vib(T[i],f_mol_all_cry_ads_com)
	q_mol_onl_cry_ads_com[i] = q_vib(T[i],f_mol_onl_cry_ads_com)
	q_all_cry_ads_com[i] = q_vib(T[i],f_all_cry_ads_com)
	q_all_cry_ads_ref[i] = q_vib(T[i],f_all_cry_ads_ref)
	q_all_cry_des_ref_opt[i] = q_vib(T[i],f_all_cry_des_ref_opt)
	q_frg_cry_des_ref_opt[i] = q_vib(T[i],f_frg_cry_des_ref_opt)
	q_frg_cry_ads_com[i] = q_vib(T[i],f_frg_cry_ads_com)
	q_frg_cry_ads_ref[i] = q_vib(T[i],f_frg_cry_ads_ref)
	
fig, ax = plt.subplots(figsize=(10,10))
#ax.plot(T, q_all_cry_ads_ref/q_all_cry_ads_com*q_h2o_cry,color='magenta',linewidth=5,label='cry ads atomonly all')
#ax.plot(T, q_frg_cry_ads_ref/q_frg_cry_ads_com*q_h2o_cry,color='orange',linewidth=5,label='cry ads atomonly frag')
ax.plot(T, q_all_cry_des_ref/q_all_cry_des_com*q_h2o_cry,color='brown',linewidth=5,label='cry des atomonly all')
ax.plot(T, q_frg_cry_des_ref/q_frg_cry_des_com*q_h2o_cry,color='yellow',linewidth=5,label='cry des atomonly frag')
ax.plot(T, q_all_cry_des_ref_opt/q_all_cry_des_com*q_h2o_cry,color='red',linewidth=5,label='cry des opt_full all')
ax.plot(T, q_frg_cry_des_ref_opt/q_frg_cry_des_com*q_h2o_cry,color='blue',linewidth=5,label='cry des opt_full frag')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('q_vib ratio', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_ylim(1e-15,1)
#ax.set_xlim(0,200)
plt.yscale('log')
plt.title('H2O')
ax.grid()
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(T, q_all_cry_ads_ref/q_all_cry_ads_com*q_h2o_cry,color='magenta',linewidth=5,label='cry ads all')
ax.plot(T, q_frg_cry_ads_ref/q_frg_cry_ads_com*q_h2o_cry,color='orange',linewidth=5,label='cry ads frag')
ax.plot(T, 1/q_mol_all_cry_ads_com,color='brown',linewidth=5,label='cry ads mol on all complex')
ax.plot(T, 1/q_mol_frg_cry_ads_com,color='red',linewidth=5,label='cry ads mol on frg complex')
ax.plot(T, 1/q_mol_onl_cry_ads_com,color='blue',linewidth=5,label='cry ads mol fragment')

ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('q_vib ratio', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_ylim(1e-15,1)
#ax.set_xlim(0,200)
plt.yscale('log')
plt.title('H2O')
ax.grid()
plt.show()

df_tmp = pd.DataFrame()
df_tmp['T'] = T
df_tmp['q_vib_des_atomonly_all'] = q_all_cry_des_ref/q_all_cry_des_com*q_h2o_cry
df_tmp['q_vib_des_atomonly_frg'] = q_frg_cry_des_ref/q_frg_cry_des_com*q_h2o_cry
df_tmp['q_vib_des_optfull_all']  = q_all_cry_des_ref_opt/q_all_cry_des_com*q_h2o_cry
df_tmp['q_vib_des_optfull_frg']  = q_frg_cry_des_ref_opt/q_frg_cry_des_com*q_h2o_cry


with open("/Users/tinaccil/Documents/code/ONIOM/H2O_cry_des_opt_vs_atomonly.csv","w+") as output:
	output.write(df_tmp.to_csv(sep="\t", index=False))

df_tmp = pd.DataFrame()
df_tmp['T'] = T
df_tmp['q_vib_ratio_all'] 		 = q_all_cry_ads_ref/q_all_cry_ads_com*q_h2o_cry
df_tmp['q_vib_ratio_all_frg'] 	 = q_frg_cry_ads_ref/q_frg_cry_ads_com*q_h2o_cry
df_tmp['q_vib_6N_frg_mol_only']  = q_h2o_cry/q_mol_onl_cry_ads_com
df_tmp['q_vib_6N_frg']  		 = q_h2o_cry/q_mol_frg_cry_ads_com
df_tmp['q_vib_6N_all']  		 = q_h2o_cry/q_mol_all_cry_ads_com
df_tmp['q_vib_frg_mol_only']     = 1/q_mol_onl_cry_ads_com
df_tmp['q_vib_frg_frg']  		 = 1/q_mol_frg_cry_ads_com
df_tmp['q_vib_frg_all']  		 = 1/q_mol_all_cry_ads_com

with open("/Users/tinaccil/Documents/code/ONIOM/q_vib_ratio_H2O_ads.csv","w+") as output:
	output.write(df_tmp.to_csv(sep="\t", index=False))

# %%
import pandas as pd
import numpy as np
from lib_rate import read_freq_gau, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_full_6n, kooji
import matplotlib.pyplot as plt

with open("/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_ammonia.csv","r") as data:
	df = pd.read_csv(data, delimiter = '\t', index_col=False)

sample 	 = [str(33), str(30),str(46)]
dH 		 = [24.297504,34.0714392,44.45355776]
freq_mol = np.array([1035.8416,1642.5685,1642.8135,3397.8782,3522.6917,3523.1565])

freq_cc_33 = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/33/freq_grain_mol/freq_grain_mol33.log')
freq_cr_33 = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/33/freq_new_deformation/freq_new_deformation33.log')

freq_cc_30 = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/30/freq_grain_mol/freq_grain_mol30.log')
freq_cr_30 = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/30/freq_new_deformation/freq_new_deformation30.log')

freq_cc_46 = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/46/freq_grain_mol/freq_grain_mol46.log')
freq_cr_46 = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/46/freq_new_deformation/freq_new_deformation46.log')

step = 5
t_fin = 600

T = np.arange(0.1, t_fin, step,dtype=float)
q_nh3_cry = np.arange(0.1, t_fin, step,dtype=float)
q_nh3_cluster = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_33_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_33_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_30_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_30_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_46_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_46_ads_ref = np.arange(0.1, t_fin, step,dtype=float)

q_mol_frg_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_mol_all_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_mol_onl_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)

f_nh3_cry = pd.Series(df['mol_iso_cry'].to_numpy(dtype=float))
f_all_cry_ads_com = pd.Series(df['NH3_cry_complex'].to_numpy(dtype=float))
f_all_cry_ads_ref = pd.Series(df['NH3_cry_ref'].to_numpy(dtype=float))
f_frg_cry_ads_com = pd.Series(df['NH3_cry_frg_complex'].to_numpy(dtype=float))
f_frg_cry_ads_ref = pd.Series(df['NH3_cry_frg_ref'].to_numpy(dtype=float))

f_mol_frg_cry_ads_com = pd.Series(df['cry_mol_frag_complex'].to_numpy(dtype=float))
f_mol_all_cry_ads_com = pd.Series(df['cry_mol_full_complex'].to_numpy(dtype=float))
f_mol_onl_cry_ads_com = pd.Series(df['cry_mol_only_complex'].to_numpy(dtype=float))

f_nh3_cry = f_nh3_cry[~np.isnan(f_nh3_cry)]
f_all_cry_ads_com = f_all_cry_ads_com[~np.isnan(f_all_cry_ads_com)]
f_all_cry_ads_ref = f_all_cry_ads_ref[~np.isnan(f_all_cry_ads_ref)]
f_frg_cry_ads_com = f_frg_cry_ads_com[~np.isnan(f_frg_cry_ads_com)]
f_frg_cry_ads_ref = f_frg_cry_ads_ref[~np.isnan(f_frg_cry_ads_ref)]

f_mol_frg_cry_ads_com = f_mol_frg_cry_ads_com[~np.isnan(f_mol_frg_cry_ads_com)]
f_mol_all_cry_ads_com = f_mol_all_cry_ads_com[~np.isnan(f_mol_all_cry_ads_com)]
f_mol_onl_cry_ads_com = f_mol_onl_cry_ads_com[~np.isnan(f_mol_onl_cry_ads_com)]


for i in range(len(T)):
	q_nh3_cry[i] 	 	 = q_vib(T[i],f_nh3_cry)
	q_nh3_cluster[i] 	 = q_vib(T[i],freq_mol)
	q_all_cry_ads_com[i] = q_vib(T[i],f_all_cry_ads_com)
	q_all_cry_ads_ref[i] = q_vib(T[i],f_all_cry_ads_ref)
	q_frg_cry_ads_com[i] = q_vib(T[i],f_frg_cry_ads_com)
	q_frg_cry_ads_ref[i] = q_vib(T[i],f_frg_cry_ads_ref)
	q_33_ads_com[i]	 = q_vib(T[i],freq_cc_33)
	q_33_ads_ref[i]	 = q_vib(T[i],freq_cr_33)
	q_30_ads_com[i]	 = q_vib(T[i],freq_cc_30)
	q_30_ads_ref[i]	 = q_vib(T[i],freq_cr_30)
	q_46_ads_com[i] 	 = q_vib(T[i],freq_cc_46)
	q_46_ads_ref[i] 	 = q_vib(T[i],freq_cr_46)
	q_mol_frg_cry_ads_com[i] = q_vib(T[i],f_mol_frg_cry_ads_com)
	q_mol_all_cry_ads_com[i] = q_vib(T[i],f_mol_all_cry_ads_com)
	q_mol_onl_cry_ads_com[i] = q_vib(T[i],f_mol_onl_cry_ads_com)
	
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(T, q_all_cry_ads_ref/q_all_cry_ads_com*q_nh3_cry,color='magenta',linewidth=5,label='NH3 cry ads all')
ax.plot(T, q_frg_cry_ads_ref/q_frg_cry_ads_com*q_nh3_cry,color='orange',linewidth=5,label='NH3 cry ads frag')
#ax.plot(T, q_33_ads_ref/q_33_ads_com*q_nh3_cluster,color='red',linewidth=5,label='NH3 33')
#ax.plot(T, q_30_ads_ref/q_30_ads_com*q_nh3_cluster,color='blue',linewidth=5,label='NH3 30')
#ax.plot(T, q_46_ads_ref/q_46_ads_com*q_nh3_cluster,color='green',linewidth=5,label='NH3 46')
ax.plot(T, q_nh3_cry/q_mol_all_cry_ads_com,color='brown',linewidth=5,label='cry ads mol on all complex')
ax.plot(T, q_nh3_cry/q_mol_frg_cry_ads_com,color='red',linewidth=5,label='cry ads mol on frg complex')
ax.plot(T, q_nh3_cry/q_mol_onl_cry_ads_com,color='blue',linewidth=5,label='cry ads mol fragment')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('q_vib ratio', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
ax.set_ylim(1e-2,1)
ax.set_xlim(0,200)
plt.yscale('log')
plt.title('NH3')
ax.grid()
plt.show()

df_tmp = pd.DataFrame()
df_tmp['T'] = T
df_tmp['q_vib_ratio_all'] 		 = q_all_cry_ads_ref/q_all_cry_ads_com*q_nh3_cry
df_tmp['q_vib_ratio_all_frg'] 	 = q_frg_cry_ads_ref/q_frg_cry_ads_com*q_nh3_cry
df_tmp['q_vib_6N_frg_mol_only']  = q_nh3_cry/q_mol_onl_cry_ads_com
df_tmp['q_vib_6N_frg']  		 = q_nh3_cry/q_mol_frg_cry_ads_com
df_tmp['q_vib_6N_all']  		 = q_nh3_cry/q_mol_all_cry_ads_com
df_tmp['q_vib_frg_mol_only']     = 1/q_mol_onl_cry_ads_com
df_tmp['q_vib_frg_frg']  		 = 1/q_mol_frg_cry_ads_com
df_tmp['q_vib_frg_all']  		 = 1/q_mol_all_cry_ads_com

with open("/Users/tinaccil/Documents/code/ONIOM/q_vib_ratio_NH3.csv","w+") as output:
	output.write(df_tmp.to_csv(sep="\t", index=False))

# %%
import pandas as pd
import numpy as np
from lib_rate import read_freq_gau, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_full_6n, kooji,read_freq
import matplotlib.pyplot as plt

with open("/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_methanol.csv","r") as data:
	df = pd.read_csv(data, delimiter = '\t', index_col=False)

sample 	 = [str(309), str(46),str(375)]
dH 		 = [20.329587,35.896064,55.065697]
freq_mol = np.array([324.616051,1032.564258,1080.517043,1164.347533,1383.287889,1479.264324,1497.553568,1516.36175,2944.922674,2989.580044,3076.188528,3758.230093])

freq_cc_309 = read_freq('/Users/tinaccil/Documents/code/ONIOM/ONIOM_CH3OH/309/grain_mol_opt.hess')
freq_cr_309 = read_freq('/Users/tinaccil/Documents/code/ONIOM/ONIOM_CH3OH/309/cluster_opt.hess')
freq_cc_46 = read_freq('/Users/tinaccil/Documents/code/ONIOM/ONIOM_CH3OH/46/grain_mol_opt.hess')
freq_cr_46 = read_freq('/Users/tinaccil/Documents/code/ONIOM/ONIOM_CH3OH/46/cluster_opt.hess')
freq_cc_375 = read_freq('/Users/tinaccil/Documents/code/ONIOM/ONIOM_CH3OH/375/grain_mol_opt.hess')
freq_cr_375 = read_freq('/Users/tinaccil/Documents/code/ONIOM/ONIOM_CH3OH/375/cluster_opt.hess')

step = 5
t_fin = 600

T = np.arange(0.1, t_fin, step,dtype=float)
q_ch3oh_cry = np.arange(0.1, t_fin, step,dtype=float)
q_ch3oh_cluster = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_all_cry_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_frg_cry_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_309_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_309_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_46_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_46_ads_ref = np.arange(0.1, t_fin, step,dtype=float)
q_375_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_375_ads_ref = np.arange(0.1, t_fin, step,dtype=float)

q_mol_frg_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_mol_all_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)
q_mol_onl_cry_ads_com = np.arange(0.1, t_fin, step,dtype=float)

f_ch3oh_cry = pd.Series(df['mol_iso_cry'].to_numpy(dtype=float))
f_all_cry_ads_com = pd.Series(df['CH3OH_cry_complex'].to_numpy(dtype=float))
f_all_cry_ads_ref = pd.Series(df['CH3OH_cry_ref'].to_numpy(dtype=float))
f_frg_cry_ads_com = pd.Series(df['CH3OH_cry_frg_complex'].to_numpy(dtype=float))
f_frg_cry_ads_ref = pd.Series(df['CH3OH_cry_frg_ref'].to_numpy(dtype=float))

f_mol_frg_cry_ads_com = pd.Series(df['cry_mol_frag_complex'].to_numpy(dtype=float))
f_mol_all_cry_ads_com = pd.Series(df['cry_mol_full_complex'].to_numpy(dtype=float))
f_mol_onl_cry_ads_com = pd.Series(df['cry_mol_only_complex'].to_numpy(dtype=float))


f_ch3oh_cry = f_ch3oh_cry[~np.isnan(f_ch3oh_cry)]
f_all_cry_ads_com = f_all_cry_ads_com[~np.isnan(f_all_cry_ads_com)]
f_all_cry_ads_ref = f_all_cry_ads_ref[~np.isnan(f_all_cry_ads_ref)]
f_frg_cry_ads_com = f_frg_cry_ads_com[~np.isnan(f_frg_cry_ads_com)]
f_frg_cry_ads_ref = f_frg_cry_ads_ref[~np.isnan(f_frg_cry_ads_ref)]

f_mol_frg_cry_ads_com = f_mol_frg_cry_ads_com[~np.isnan(f_mol_frg_cry_ads_com)]
f_mol_all_cry_ads_com = f_mol_all_cry_ads_com[~np.isnan(f_mol_all_cry_ads_com)]
f_mol_onl_cry_ads_com = f_mol_onl_cry_ads_com[~np.isnan(f_mol_onl_cry_ads_com)]

for i in range(len(T)):
	q_ch3oh_cry[i] 	 	 = q_vib(T[i],f_ch3oh_cry)
	q_ch3oh_cluster[i] 	 = q_vib(T[i],freq_mol)
	q_all_cry_ads_com[i] = q_vib(T[i],f_all_cry_ads_com)
	q_all_cry_ads_ref[i] = q_vib(T[i],f_all_cry_ads_ref)
	q_frg_cry_ads_com[i] = q_vib(T[i],f_frg_cry_ads_com)
	q_frg_cry_ads_ref[i] = q_vib(T[i],f_frg_cry_ads_ref)
	q_309_ads_com[i]	 = q_vib(T[i],freq_cc_309)
	q_309_ads_ref[i]	 = q_vib(T[i],freq_cr_309)
	q_46_ads_com[i]	 = q_vib(T[i],freq_cc_46)
	q_46_ads_ref[i]	 = q_vib(T[i],freq_cr_46)
	q_375_ads_com[i] 	 = q_vib(T[i],freq_cc_375)
	q_375_ads_ref[i] 	 = q_vib(T[i],freq_cr_375)
	q_mol_frg_cry_ads_com[i] = q_vib(T[i],f_mol_frg_cry_ads_com)
	q_mol_all_cry_ads_com[i] = q_vib(T[i],f_mol_all_cry_ads_com)
	q_mol_onl_cry_ads_com[i] = q_vib(T[i],f_mol_onl_cry_ads_com)
	
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(T, q_all_cry_ads_ref/q_all_cry_ads_com*q_ch3oh_cry,color='magenta',linewidth=5,label='CH3OH cry ads all')
ax.plot(T, q_frg_cry_ads_ref/q_frg_cry_ads_com*q_ch3oh_cry,color='orange',linewidth=5,label='CH3OH cry ads frag')
ax.plot(T, 1/q_mol_all_cry_ads_com,color='brown',linewidth=5,label='cry ads mol on all complex')
ax.plot(T, 1/q_mol_frg_cry_ads_com,color='red',linewidth=5,label='cry ads mol on frg complex')
ax.plot(T, 1/q_mol_onl_cry_ads_com,color='blue',linewidth=5,label='cry ads mol fragment')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('q_vib ratio', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
ax.set_ylim(1e-2,1)
ax.set_xlim(0,200)
plt.title('CH3OH')
plt.yscale('log')
ax.grid()
plt.show()

df_tmp = pd.DataFrame()
df_tmp['T'] = T
df_tmp['q_vib_ratio_all'] 		 = q_all_cry_ads_ref/q_all_cry_ads_com*q_ch3oh_cry
df_tmp['q_vib_ratio_all_frg'] 	 = q_frg_cry_ads_ref/q_frg_cry_ads_com*q_ch3oh_cry
df_tmp['q_vib_6N_frg_mol_only']  = q_ch3oh_cry/q_mol_onl_cry_ads_com
df_tmp['q_vib_6N_frg']  		 = q_ch3oh_cry/q_mol_frg_cry_ads_com
df_tmp['q_vib_6N_all']  		 = q_ch3oh_cry/q_mol_all_cry_ads_com
df_tmp['q_vib_frg_mol_only']     = 1/q_mol_onl_cry_ads_com
df_tmp['q_vib_frg_frg']  		 = 1/q_mol_frg_cry_ads_com
df_tmp['q_vib_frg_all']  		 = 1/q_mol_all_cry_ads_com

with open("/Users/tinaccil/Documents/code/ONIOM/q_vib_ratio_CH3OH.csv","w+") as output:
	output.write(df_tmp.to_csv(sep="\t", index=False))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv

step = 10
t_fin = 310

tmp_dir = '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
tmp_gc = '/freq_new_deformation/freq_new_deformation'
tmp_gg = '/freq_grain_mol/freq_grain_mol'

h2o_dh 		= [0,0,0]#[30.893808,44.575777,56.552372]
h2o_dh_des	= 0#68.49
h2o_dh_ads	= 0#50.37
h2o_frq		= np.array([1711.76,3737.17,3849.08])
h2o_smp		= [str(33), str(30),str(46)]
h2o_csv		= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_h20_resume.csv'
nh3_dh		= [0,0,0]#[24.297504,34.0714392,44.45355776]
nh3_dh_ads	= 0#55.22
nh3_frq		= np.array([1035.8416,1642.5685,1642.8135,3397.8782,3522.6917,3523.1565])
nh3_smp		= [str(33), str(30),str(46)]
nh3_csv		= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_ammonia.csv'
ch3oh_dh	= [0,0,0]#[20.329587,35.896064,55.065697]
ch3oh_dh_ads= 0#60.11
ch3oh_frq	= np.array([324.616051,1032.564258,1080.517043,1164.347533,1383.287889,1479.264324,1497.553568,1516.36175,2944.922674,2989.580044,3076.188528,3758.230093])
ch3oh_smp	= [str(309), str(46),str(375)]
ch3oh_csv	= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_methanol.csv'

T = np.arange(10, t_fin, step,dtype=float)
tmp_H2O_309		= np.arange(10, t_fin, step,dtype=float)
tmp_H2O_46		= np.arange(10, t_fin, step,dtype=float)
tmp_H2O_375		= np.arange(10, t_fin, step,dtype=float)
tmp_H2O_des		= np.arange(10, t_fin, step,dtype=float)
tmp_H2O_ads		= np.arange(10, t_fin, step,dtype=float)
tmp_NH3_33		= np.arange(10, t_fin, step,dtype=float)
tmp_NH3_30		= np.arange(10, t_fin, step,dtype=float)
tmp_NH3_46		= np.arange(10, t_fin, step,dtype=float)
tmp_NH3_ads		= np.arange(10, t_fin, step,dtype=float)
tmp_CH3OH_309	= np.arange(10, t_fin, step,dtype=float)
tmp_CH3OH_46	= np.arange(10, t_fin, step,dtype=float)
tmp_CH3OH_375	= np.arange(10, t_fin, step,dtype=float)
tmp_CH3OH_ads	= np.arange(10, t_fin, step,dtype=float)

for i in range(len(T)):
	tmp_H2O_309[i]		= BH_t(T[i],h2o_frq,read_freq(tmp_dir+'H2O/'+h2o_smp[0]+'/cluster_opt.hess'),read_freq(tmp_dir+'H2O/'+h2o_smp[0]+'/grain_mol_opt.hess'),h2o_dh[0])
	tmp_H2O_46[i]		= BH_t(T[i],h2o_frq,read_freq(tmp_dir+'H2O/'+h2o_smp[1]+'/cluster_opt.hess'),read_freq(tmp_dir+'H2O/'+h2o_smp[1]+'/grain_mol_opt.hess'),h2o_dh[1])
	tmp_H2O_375[i]		= BH_t(T[i],h2o_frq,read_freq(tmp_dir+'H2O/'+h2o_smp[2]+'/cluster_opt.hess'),read_freq(tmp_dir+'H2O/'+h2o_smp[2]+'/grain_mol_opt.hess'),h2o_dh[2])
	tmp_H2O_des[i]		= BH_t(T[i],read_freq_from_csv(h2o_csv,'mol_iso_cry'),read_freq_from_csv(h2o_csv,'cry_des_all_ref'),read_freq_from_csv(h2o_csv,'cry_des_all_complex'),h2o_dh_des)
	tmp_H2O_ads[i]		= BH_t(T[i],read_freq_from_csv(h2o_csv,'mol_iso_cry'),read_freq_from_csv(h2o_csv,'cry_ads_all_ref'),read_freq_from_csv(h2o_csv,'cry_ads_all_complex'),h2o_dh_ads)
	tmp_NH3_33[i]		= BH_t(T[i],nh3_frq,read_freq_gau(tmp_dir+'NH3/'+nh3_smp[0]+tmp_gc+nh3_smp[0]+'.log'),read_freq_gau(tmp_dir+'NH3/'+nh3_smp[0]+tmp_gg+nh3_smp[0]+'.log'),nh3_dh[0])
	tmp_NH3_30[i]		= BH_t(T[i],nh3_frq,read_freq_gau(tmp_dir+'NH3/'+nh3_smp[1]+tmp_gc+nh3_smp[1]+'.log'),read_freq_gau(tmp_dir+'NH3/'+nh3_smp[1]+tmp_gg+nh3_smp[1]+'.log'),nh3_dh[1])
	tmp_NH3_46[i]		= BH_t(T[i],nh3_frq,read_freq_gau(tmp_dir+'NH3/'+nh3_smp[2]+tmp_gc+nh3_smp[2]+'.log'),read_freq_gau(tmp_dir+'NH3/'+nh3_smp[2]+tmp_gg+nh3_smp[2]+'.log'),nh3_dh[2])
	tmp_NH3_ads[i]		= BH_t(T[i],read_freq_from_csv(nh3_csv,'mol_iso_cry'),read_freq_from_csv(nh3_csv,'NH3_cry_ref'),read_freq_from_csv(nh3_csv,'NH3_cry_complex'),nh3_dh_ads)
	tmp_CH3OH_309[i]	= BH_t(T[i],ch3oh_frq,read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[0]+'/cluster_opt.hess'),read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[0]+'/grain_mol_opt.hess'),ch3oh_dh[0])
	tmp_CH3OH_46[i]		= BH_t(T[i],ch3oh_frq,read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[1]+'/cluster_opt.hess'),read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[1]+'/grain_mol_opt.hess'),ch3oh_dh[1])
	tmp_CH3OH_375[i]	= BH_t(T[i],ch3oh_frq,read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[2]+'/cluster_opt.hess'),read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[2]+'/grain_mol_opt.hess'),ch3oh_dh[2])
	tmp_CH3OH_ads[i]	= BH_t(T[i],read_freq_from_csv(ch3oh_csv,'mol_iso_cry'),read_freq_from_csv(ch3oh_csv,'CH3OH_cry_ref'),read_freq_from_csv(ch3oh_csv,'CH3OH_cry_complex'),ch3oh_dh_ads)

df_tmp = pd.DataFrame()
df_tmp['T'] 		= T
df_tmp['H2O_309']	= tmp_H2O_309
df_tmp['H2O_46']	= tmp_H2O_46
df_tmp['H2O_375']	= tmp_H2O_375
df_tmp['H2O_des']	= tmp_H2O_des
df_tmp['H2O_ads']	= tmp_H2O_ads
df_tmp['NH3_33']	= tmp_NH3_33
df_tmp['NH3_30']	= tmp_NH3_30
df_tmp['NH3_46']	= tmp_NH3_46
df_tmp['NH3_ads']	= tmp_NH3_ads
df_tmp['CH3OH_309']	= tmp_CH3OH_309
df_tmp['CH3OH_46']	= tmp_CH3OH_46
df_tmp['CH3OH_375']	= tmp_CH3OH_375
df_tmp['CH3OH_ads']	= tmp_CH3OH_ads

with open("/Users/tinaccil/Documents/code/ONIOM/BH_t.csv","w+") as output:
	output.write(df_tmp.to_csv(sep="\t", index=False))

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(T, tmp_H2O_309,color='magenta',linewidth=5,label='H2O_309')
ax.plot(T, tmp_H2O_46,color='orange',linewidth=5,label='H2O_46')
ax.plot(T, tmp_H2O_375,color='red',linewidth=5,label='H2O_375')
ax.plot(T, tmp_H2O_des,color='blue',linewidth=5,label='H2O_des')
ax.plot(T, tmp_H2O_ads,color='green',linewidth=5,label='H2O_ads')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('BH(T)-BH(0) kJ/mol', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_ylim(1e-2,1)
#ax.set_xlim(0,200)
#plt.yscale('log')
plt.title('H2O')
ax.grid()
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(T, tmp_NH3_33,color='magenta',linewidth=5,label='NH3_33')
ax.plot(T, tmp_NH3_30,color='orange',linewidth=5,label='NH3_30')
ax.plot(T, tmp_NH3_46,color='red',linewidth=5,label='NH3_46')
ax.plot(T, tmp_NH3_ads,color='blue',linewidth=5,label='NH3_ads')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('BH(T)-BH(0) kJ/mol', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_ylim(1e-2,1)
#ax.set_xlim(0,200)
#plt.yscale('log')
plt.title('NH3')
ax.grid()
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(T, tmp_CH3OH_309,color='magenta',linewidth=5,label='CH3OH_309')
ax.plot(T, tmp_CH3OH_46,color='orange',linewidth=5,label='CH3OH_46')
ax.plot(T, tmp_CH3OH_375,color='red',linewidth=5,label='CH3OH_375')
ax.plot(T, tmp_CH3OH_ads,color='blue',linewidth=5,label='CH3OH_ads')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('BH(T)-BH(0) kJ/mol', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_ylim(1e-2,1)
#ax.set_xlim(0,200)
#plt.yscale('log')
plt.title('CH3OH')
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_HH

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
step 	= 1
beta 	= 0.04#1e-27
N_i  	= 1
A	 	= 1e-19
t_fin 	= 300

#### sample parameters ####
h2o_dh 		= [30.893808,44.575777,56.552372]
h2o_dh_des	= 68.49
h2o_dh_ads	= 50.37
h2o_frq		= np.array([1711.76,3737.17,3849.08])
h2o_smp		= [str(370), str(470),str(63)]
h2o_csv		= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_h20_resume.csv'
tmp_dir 	= '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
mass_h20 	= 18.02
sim_h20	 	= 2
Ic_h20 	 	= [1.83,1.21,0.62]

T 			= np.arange(1, t_fin, step,dtype=float)
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)

N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

tmp_s = 2

freq_c = read_freq(tmp_dir+'H2O/'+h2o_smp[tmp_s]+'/cluster_opt.hess')
freq_g = read_freq(tmp_dir+'H2O/'+h2o_smp[tmp_s]+'/grain_mol_opt.hess')

df = pd.DataFrame()
df['T']  = T

Pre_HH		= pre_factor_HH(mass_h20,A,h2o_dh[tmp_s])
for i in range(len(T)):
	bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,h2o_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_HH,bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[h2o_smp[tmp_s] + '_TPD_HH']   = dN.copy()
df[h2o_smp[tmp_s] + '_rate_HH']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i]	= pre_factor_full(T[i],mass_h20,A,sim_h20,Ic_h20,h2o_frq,freq_c,freq_g)
	bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,h2o_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[h2o_smp[tmp_s] + '_TPD_full']   = dN.copy()
df[h2o_smp[tmp_s] + '_pre_full']   = Pre_exp.copy()
df[h2o_smp[tmp_s] + '_rate_full']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i] 	= pre_factor_approx(T[i],mass_h20,A,sim_h20,Ic_h20)
	bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,h2o_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[h2o_smp[tmp_s]  + '_TPD_Tait']  = dN.copy()
df[h2o_smp[tmp_s]  + '_pre_Tait']  = Pre_exp.copy()
df[h2o_smp[tmp_s]  + '_rate_Tait'] = Rate.copy()


with open("/Users/tinaccil/Documents/code/ONIOM/H2O_" + h2o_smp[tmp_s] + "_all.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN_f = pd.Series(df[h2o_smp[tmp_s] + '_TPD_full'].to_numpy(dtype=float))
dN_t = pd.Series(df[h2o_smp[tmp_s] + '_TPD_Tait'].to_numpy(dtype=float))
dN_h = pd.Series(df[h2o_smp[tmp_s] + '_TPD_HH'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_f,color='red',linewidth=5,label='full')
ax.plot(T, dN_t,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_h,color='black',linewidth=5,label='HH')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_HH

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
step 	= 1
beta 	= 0.04#1e-27
N_i  	= 1
A	 	= 1e-19
t_fin 	= 300

#### sample parameters ####
h2o_csv		= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_h20_resume.csv'
tmp_dir 	= '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
h2o_dh		= [50.37,68.49]
h2o_frq		= read_freq_from_csv(h2o_csv,'mol_iso_cry')
h2o_smp		= ['ads', 'des']
mass_h20 	= 18.02
sim_h20	 	= 2
Ic_h20 	 	= [1.83,1.21,0.62]

T 			= np.arange(1, t_fin, step,dtype=float)
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)

N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

tmp_s = 1

freq_c = read_freq_from_csv(h2o_csv,'cry_'+h2o_smp[tmp_s]+'_all_ref')
freq_g = read_freq_from_csv(h2o_csv,'cry_'+h2o_smp[tmp_s]+'_all_complex')

df = pd.DataFrame()
df['T']  = T

Pre_HH		= pre_factor_HH(mass_h20,A,h2o_dh[tmp_s])
for i in range(len(T)):
	bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,h2o_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_HH,bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[h2o_smp[tmp_s] + '_TPD_HH']   = dN.copy()
df[h2o_smp[tmp_s] + '_rate_HH']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i]	= pre_factor_full(T[i],mass_h20,A,sim_h20,Ic_h20,h2o_frq,freq_c,freq_g)
	bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,h2o_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[h2o_smp[tmp_s] + '_TPD_full']   = dN.copy()
df[h2o_smp[tmp_s] + '_pre_full']   = Pre_exp.copy()
df[h2o_smp[tmp_s] + '_rate_full']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i] 	= pre_factor_approx(T[i],mass_h20,A,sim_h20,Ic_h20)
	bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,h2o_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[h2o_smp[tmp_s]  + '_TPD_Tait']  = dN.copy()
df[h2o_smp[tmp_s]  + '_pre_Tait']  = Pre_exp.copy()
df[h2o_smp[tmp_s]  + '_rate_Tait'] = Rate.copy()


with open("/Users/tinaccil/Documents/code/ONIOM/H2O_" + h2o_smp[tmp_s] + "_all_cry_"+h2o_smp[tmp_s]+".csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN_f = pd.Series(df[h2o_smp[tmp_s] + '_TPD_full'].to_numpy(dtype=float))
dN_t = pd.Series(df[h2o_smp[tmp_s] + '_TPD_Tait'].to_numpy(dtype=float))
dN_h = pd.Series(df[h2o_smp[tmp_s] + '_TPD_HH'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_f,color='red',linewidth=5,label='full')
ax.plot(T, dN_t,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_h,color='black',linewidth=5,label='HH')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_HH

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
step 	= 1
beta 	= 0.04#1e-27
N_i  	= 1
A	 	= 1e-19
t_fin 	= 300

#### sample parameters ####
ch3oh_dh	= [20.329587,35.896064,55.065697]
ch3oh_dh_ads= 60.11
ch3oh_frq	= np.array([324.616051,1032.564258,1080.517043,1164.347533,1383.287889,1479.264324,1497.553568,1516.36175,2944.922674,2989.580044,3076.188528,3758.230093])
ch3oh_smp	= [str(309), str(46),str(375)]
ch3oh_csv	= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_methanol.csv'
tmp_dir 	= '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
mass_ch3oh 	= 32.04
sim_ch3oh 	= 1
Ic_ch3oh	= [21.06,20.24,4.01]

T 			= np.arange(1, t_fin, step,dtype=float)
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)

N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

tmp_s = 2

freq_c = read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[tmp_s]+'/cluster_opt.hess')
freq_g = read_freq(tmp_dir+'CH3OH/'+ch3oh_smp[tmp_s]+'/grain_mol_opt.hess')

df = pd.DataFrame()
df['T']  = T

Pre_HH		= pre_factor_HH(mass_ch3oh,A,ch3oh_dh[tmp_s])
for i in range(len(T)):
	bh			= BH_t(T[i],ch3oh_frq,freq_c,freq_g,ch3oh_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_HH,bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[ch3oh_smp[tmp_s] + '_TPD_HH']   = dN.copy()
df[ch3oh_smp[tmp_s] + '_rate_HH']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i]	= pre_factor_full(T[i],mass_ch3oh,A,sim_ch3oh,Ic_ch3oh,ch3oh_frq,freq_c,freq_g)
	bh			= BH_t(T[i],ch3oh_frq,freq_c,freq_g,ch3oh_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[ch3oh_smp[tmp_s] + '_TPD_full']   = dN.copy()
df[ch3oh_smp[tmp_s] + '_pre_full']   = Pre_exp.copy()
df[ch3oh_smp[tmp_s] + '_rate_full']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i] 	= pre_factor_approx(T[i],mass_ch3oh,A,sim_ch3oh,Ic_ch3oh)
	bh			= BH_t(T[i],ch3oh_frq,freq_c,freq_g,ch3oh_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[ch3oh_smp[tmp_s]  + '_TPD_Tait']  = dN.copy()
df[ch3oh_smp[tmp_s]  + '_pre_Tait']  = Pre_exp.copy()
df[ch3oh_smp[tmp_s]  + '_rate_Tait'] = Rate.copy()

#print(df[df[ch3oh_smp[tmp_s]  + '_TPD_full'] == df[ch3oh_smp[tmp_s]  + '_TPD_full'].max()])

with open("/Users/tinaccil/Documents/code/ONIOM/CH3OH_" + ch3oh_smp[tmp_s] + "_all.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN_f = pd.Series(df[ch3oh_smp[tmp_s] + '_TPD_full'].to_numpy(dtype=float))
dN_t = pd.Series(df[ch3oh_smp[tmp_s] + '_TPD_Tait'].to_numpy(dtype=float))
dN_h = pd.Series(df[ch3oh_smp[tmp_s] + '_TPD_HH'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_f,color='red',linewidth=5,label='full')
ax.plot(T, dN_t,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_h,color='black',linewidth=5,label='HH')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_HH

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
step 	= 0.1
beta 	= 0.04#1e-27
N_i  	= 1
A	 	= 1e-19
step 	= 1
t_fin 	= 300

#### sample parameters ####
ch3oh_csv	= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_methanol.csv'
tmp_dir 	= '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
h2o_frq		= read_freq_from_csv(ch3oh_csv,'mol_iso_cry')
ch3oh_smp	= ['ads']
ch3oh_dh	= [60.11]
mass_ch3oh 	= 32.04
sim_ch3oh 	= 1
Ic_ch3oh	= [21.06,20.24,4.01]

T 			= np.arange(1, t_fin, step,dtype=float)
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)

N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

tmp_s = 0

freq_c = read_freq_from_csv(ch3oh_csv,'CH3OH_cry_ref')
freq_g = read_freq_from_csv(ch3oh_csv,'CH3OH_cry_complex')

df = pd.DataFrame()
df['T']  = T

Pre_HH		= pre_factor_HH(mass_ch3oh,A,ch3oh_dh[tmp_s])
for i in range(len(T)):
	bh			= BH_t(T[i],ch3oh_frq,freq_c,freq_g,ch3oh_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_HH,bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[ch3oh_smp[tmp_s] + '_TPD_HH']   = dN.copy()
df[ch3oh_smp[tmp_s] + '_rate_HH']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i]	= pre_factor_full(T[i],mass_ch3oh,A,sim_ch3oh,Ic_ch3oh,ch3oh_frq,freq_c,freq_g)
	bh			= BH_t(T[i],ch3oh_frq,freq_c,freq_g,ch3oh_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[ch3oh_smp[tmp_s] + '_TPD_full']   = dN.copy()
df[ch3oh_smp[tmp_s] + '_pre_full']   = Pre_exp.copy()
df[ch3oh_smp[tmp_s] + '_rate_full']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i] 	= pre_factor_approx(T[i],mass_ch3oh,A,sim_ch3oh,Ic_ch3oh)
	bh			= BH_t(T[i],ch3oh_frq,freq_c,freq_g,ch3oh_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[ch3oh_smp[tmp_s]  + '_TPD_Tait']  = dN.copy()
df[ch3oh_smp[tmp_s]  + '_pre_Tait']  = Pre_exp.copy()
df[ch3oh_smp[tmp_s]  + '_rate_Tait'] = Rate.copy()

with open("/Users/tinaccil/Documents/code/ONIOM/CH3OH_" + ch3oh_smp[tmp_s] + "_all_cry.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN_f = pd.Series(df[ch3oh_smp[tmp_s] + '_TPD_full'].to_numpy(dtype=float))
dN_t = pd.Series(df[ch3oh_smp[tmp_s] + '_TPD_Tait'].to_numpy(dtype=float))
dN_h = pd.Series(df[ch3oh_smp[tmp_s] + '_TPD_HH'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_f,color='red',linewidth=5,label='full')
ax.plot(T, dN_t,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_h,color='black',linewidth=5,label='HH')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_HH

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
beta 	= 0.04#1e-27
N_i  	= 1
A	 	= 1e-19
step 	= 1
t_fin 	= 300

#### sample parameters ####
nh3_csv		= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_ammonia.csv'
tmp_dir 	= '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
nh3_frq		= read_freq_from_csv(nh3_csv,'mol_iso_cry')
nh3_smp		= ['ads']
nh3_dh		= [55.22]
mass_nh3 	= 17.03
sim_nh3 	= 3
Ic_nh3		= [2.76,1.71,1.71]

T 			= np.arange(1, t_fin, step,dtype=float)
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)

N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

tmp_s = 0

freq_c = read_freq_from_csv(nh3_csv,'NH3_cry_ref')
freq_g = read_freq_from_csv(nh3_csv,'NH3_cry_complex')

df = pd.DataFrame()
df['T']  = T

Pre_HH		= pre_factor_HH(mass_nh3,A,nh3_dh[tmp_s])
for i in range(len(T)):
	bh			= BH_t(T[i],nh3_frq,freq_c,freq_g,nh3_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_HH,bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[nh3_smp[tmp_s] + '_TPD_HH']   = dN.copy()
df[nh3_smp[tmp_s] + '_rate_HH']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i]	= pre_factor_full(T[i],mass_nh3,A,sim_nh3,Ic_nh3,nh3_frq,freq_c,freq_g)
	bh			= BH_t(T[i],nh3_frq,freq_c,freq_g,nh3_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[nh3_smp[tmp_s] + '_TPD_full']   = dN.copy()
df[nh3_smp[tmp_s] + '_pre_full']   = Pre_exp.copy()
df[nh3_smp[tmp_s] + '_rate_full']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i] 	= pre_factor_approx(T[i],mass_nh3,A,sim_nh3,Ic_nh3)
	bh			= BH_t(T[i],nh3_frq,freq_c,freq_g,nh3_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[nh3_smp[tmp_s]  + '_TPD_Tait']  = dN.copy()
df[nh3_smp[tmp_s]  + '_pre_Tait']  = Pre_exp.copy()
df[nh3_smp[tmp_s]  + '_rate_Tait'] = Rate.copy()

with open("/Users/tinaccil/Documents/code/ONIOM/NH3_" + nh3_smp[tmp_s] + "_all_cry.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN_f = pd.Series(df[nh3_smp[tmp_s] + '_TPD_full'].to_numpy(dtype=float))
dN_t = pd.Series(df[nh3_smp[tmp_s] + '_TPD_Tait'].to_numpy(dtype=float))
dN_h = pd.Series(df[nh3_smp[tmp_s] + '_TPD_HH'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_f,color='red',linewidth=5,label='full')
ax.plot(T, dN_t,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_h,color='black',linewidth=5,label='HH')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import BH_t, read_freq_gau, read_freq, read_freq_from_csv, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_HH

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
beta 	= 0.04#1e-27
N_i  	= 1
A	 	= 1e-19
step 	= 1
t_fin 	= 300

#### sample parameters ####
nh3_csv		= '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/freq_ammonia.csv'
tmp_dir 	= '/Users/tinaccil/Documents/code/ONIOM/ONIOM_'
nh3_frq		= np.array([1035.8416,1642.5685,1642.8135,3397.8782,3522.6917,3523.1565])
nh3_smp		= [str(33), str(30),str(46)]
nh3_dh		= [24.297504,34.0714392,44.45355776]
mass_nh3 	= 17.03
sim_nh3 	= 3
Ic_nh3		= [2.76,1.71,1.71]

T 			= np.arange(1, t_fin, step,dtype=float)
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)

N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

tmp_s = 2

freq_c = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/'+ nh3_smp[tmp_s] +'/freq_new_deformation/freq_new_deformation' + nh3_smp[tmp_s] + '.log')
freq_g = read_freq_gau('/Users/tinaccil/Documents/code/ONIOM/ONIOM_NH3/'+ nh3_smp[tmp_s] +'/freq_grain_mol/freq_grain_mol' + nh3_smp[tmp_s] + '.log')

df = pd.DataFrame()
df['T']  = T

Pre_HH		= pre_factor_HH(mass_nh3,A,nh3_dh[tmp_s])
for i in range(len(T)):
	bh			= BH_t(T[i],nh3_frq,freq_c,freq_g,nh3_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_HH,bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[nh3_smp[tmp_s] + '_TPD_HH']   = dN.copy()
df[nh3_smp[tmp_s] + '_rate_HH']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i]	= pre_factor_full(T[i],mass_nh3,A,sim_nh3,Ic_nh3,nh3_frq,freq_c,freq_g)
	bh			= BH_t(T[i],nh3_frq,freq_c,freq_g,nh3_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[nh3_smp[tmp_s] + '_TPD_full']   = dN.copy()
df[nh3_smp[tmp_s] + '_pre_full']   = Pre_exp.copy()
df[nh3_smp[tmp_s] + '_rate_full']  = Rate.copy()

N_i  = 1
Pre_exp		= np.arange(1, t_fin, step,dtype=float)
Rate	    = np.arange(1, t_fin, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Pre_exp[i] 	= pre_factor_approx(T[i],mass_nh3,A,sim_nh3,Ic_nh3)
	bh			= BH_t(T[i],nh3_frq,freq_c,freq_g,nh3_dh[tmp_s])
	Rate[i]		= RH_DesRate(T[i],Pre_exp[i],bh)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp

df[nh3_smp[tmp_s]  + '_TPD_Tait']  = dN.copy()
df[nh3_smp[tmp_s]  + '_pre_Tait']  = Pre_exp.copy()
df[nh3_smp[tmp_s]  + '_rate_Tait'] = Rate.copy()

with open("/Users/tinaccil/Documents/code/ONIOM/NH3_" + nh3_smp[tmp_s] + "_all.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN_f = pd.Series(df[nh3_smp[tmp_s] + '_TPD_full'].to_numpy(dtype=float))
dN_t = pd.Series(df[nh3_smp[tmp_s] + '_TPD_Tait'].to_numpy(dtype=float))
dN_h = pd.Series(df[nh3_smp[tmp_s] + '_TPD_HH'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_f,color='red',linewidth=5,label='full')
ax.plot(T, dN_t,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_h,color='black',linewidth=5,label='HH')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

# %%
import pandas as pd 
import numpy as np
path = '/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/H2O_63_all.csv'
with open(path,"r") as data:
	df = pd.read_csv(data, delimiter = '\t', index_col=False)
print('Full:')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[df['63_TPD_full']==df['63_TPD_full'].max()])
print('Tait:')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[df['63_TPD_Tait']==df['63_TPD_Tait'].max()])
print('HH:')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[df['63_TPD_HH']==df['63_TPD_HH'].max()])

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit, fsolve
from scipy import optimize
from lib_rate import read_freq_gau, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_full_6n, kooji

def kooji(t,alpha,beta,gamma):
	"""
	Arrehnius-kooji equation
	t: Temperature
	alpha, beta and gamma: the parameters in K
	"""
	return  alpha * (t / 300) ** beta * np.exp( - gamma / t)

tmp_s = 0
dh 		= [30.893808,44.575777,56.552372]
sample	= [str(370), str(470),str(63)]


with open("/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/H2O_"+sample[tmp_s]+"_all.csv","r") as data:
	df = pd.read_csv(data, delimiter = '\t', index_col=False)

KB = 1.3806488e-23
H  = 6.62606957e-34
C = 2.99792458e10
R = 8.3144621
AV = 6.0221415e23
AMUtoKG = 1.66053886e-27
CMtokJmol = 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK = 1.4387862961655296
kjtokcal = 4.184
KJMOLtoK= 120.2731159571
MHZtoK =  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv = 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM = 1.660539e-47


A	 	 = 1e-19

beta = 0.04
N_i  = 1

df = df[df['T']>20]
#df = df[df['T']<200]
#df = df[df['T']%3==0]

T = pd.Series(df['T'].to_numpy(dtype=float))
k = pd.Series(df[sample[tmp_s]+'_rate_full'].to_numpy(dtype=float))
ka = pd.Series(df[sample[tmp_s]+'_rate_Tait'].to_numpy(dtype=float))
#k  = k / A

print(dh[tmp_s]*KJMOLtoK)

popt_kooji, pcov = curve_fit(kooji, T, k,p0=[1e17,-0.1,dh[tmp_s]*KJMOLtoK],bounds=([0,-np.inf,dh[tmp_s]*KJMOLtoK-100],[np.inf,np.inf,dh[tmp_s]*KJMOLtoK+100]), maxfev=500000000)
print('Alpha: ' + str(f"{popt_kooji[0]:.3E}") + '\nBeta: ' + str(f"{popt_kooji[1]:.3E}") + '\nGamma: ' + str(f"{popt_kooji[2]:.3E}"))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, k,color='blue',linewidth=1,linestyle='--',label='Full')
ax.plot(T, ka,color='green',linewidth=1,linestyle='--',label='Tait')
ax.plot(T, kooji(T, *popt_kooji), color='r', linestyle='--',label='fit',linewidth=1)
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('k [s-1]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(60,62.5)
#ax.set_xlim(80,120)
#ax.set_ylim(1e-37,1e-35)
plt.yscale('log')
ax.grid()
plt.show()


step = 1
beta = 0.04
N_i  = 1
Rate 	    = np.arange(21, 300, step,dtype=float)
N	        = np.zeros(len(T),dtype=float)
dN	        = np.zeros(len(T),dtype=float)

for i in range(len(T)):
	Rate[i]		  = kooji(T[i],*popt_kooji)
	if i == 0:
		N[i]	= N_i - Rate[i] / beta * N_i * step
		dN[i]  = Rate[i] / beta * N_i * step
	else:
		tmp = Rate[i] / beta * N[i-1] * step
		if N[i-1] - tmp <= 0:
			N[i] = 0
		else:
			N[i]	 = N[i-1] - tmp
			dN[i]   = tmp
dN_k = dN

df[sample[tmp_s]+'_TPD_kooji'] = dN
df[sample[tmp_s]+'_rate_kooji'] = Rate

dN_f = pd.Series(df[sample[tmp_s]+'_TPD_full'].to_numpy(dtype=float))
dN_a = pd.Series(df[sample[tmp_s]+'_TPD_Tait'].to_numpy(dtype=float))

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[df[sample[tmp_s]+'_TPD_kooji']==df[sample[tmp_s]+'_TPD_kooji'].max()])

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN_a,color='blue',linewidth=5,label='Tait')
ax.plot(T, dN_f,color='red',linewidth=5,label='Full')
ax.plot(T, dN_k,color='black',linewidth=5,label='kooji')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [molecules]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(155,190)
ax.grid()
plt.show()

alpha 	= popt_kooji[0]
nu 		= popt_kooji[1]
gamma 	= popt_kooji[2]

def tpd_peak(T):
	"""
	Arrehnius-kooji equation
	t: Temperature
	alpha, beta and gamma: the parameters in K
	"""
	return  nu * T + gamma - 1 / beta * T * T * alpha * (T / 300) ** nu * np.exp( - gamma / T)

popt_tpd_peak = optimize.bisect(tpd_peak, 1,300)
print(popt_tpd_peak)

df_f = pd.DataFrame()
df_f['T'] = df['T']
df_f[sample[tmp_s]+'_TPD_kooji'] = df[sample[tmp_s]+'_TPD_kooji']
df_f[sample[tmp_s]+'_TPD_full'] = df[sample[tmp_s]+'_TPD_full']
df_f[sample[tmp_s]+'_rate_full'] = df[sample[tmp_s]+'_rate_full']
df_f[sample[tmp_s]+'_rate_kooji'] = df[sample[tmp_s]+'_rate_kooji']

with open("/Users/tinaccil/Documents/code/ONIOM/H2O_" + sample[tmp_s] + "_fit.csv","w+") as output:
	output.write(df_f.to_csv(sep="\t", index=False))

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import read_freq_gau, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_full_6n, kooji, read_freq, BH_t

def gaussian(x,sigma,mean):
    return 1 / sigma / np.sqrt(2 * np.pi) * np.exp(-((x - mean)**2 / (2 * sigma**2)))

with open("/Users/tinaccil/Documents/code/ONIOM/ONIOM_H2O_varie/BE_rendundat.csv","r") as data:
	df_be = pd.read_csv(data, delimiter = '\t', index_col=False)

df_be = df_be[df_be['Rendundat'] == False]

df_be['ZPE_kjmol'] = (df_be['ZPE_complex'] - df_be['ZPE_cluster'] - 0.02118242) * 6.02214076 * 100 * 4.359748199
df_be['BE_B973c_kJmol'] = - (df_be['ONIOM_complex_B973c'] - df_be['ONIOM_cluster_B973c'] - (-76.398366805927)) * 6.02214076 * 100 * 4.359748199
df_be['BH_B973c_kJmol'] = df_be['BE_B973c_kJmol'] - df_be['ZPE_kjmol']
df_be['BE_dlpno_kJmol'] = - (df_be['ONIOM_complex_DLPNO'] - df_be['ONIOM_cluster_DLPNO'] - (-76.342142464944)) * 6.02214076 * 100 * 4.359748199
df_be['BE_dlpno_kJmol'] = df_be['BE_dlpno_kJmol'] - df_be['BSSE'] * 6.02214076 * 100 * 4.359748199
df_be['BH_dlpno_kJmol'] = df_be['BE_dlpno_kJmol'] - df_be['ZPE_kjmol']
df_be['BE_e_dlpno_kJmol'] = - (df_be['ONIOM_complex_DLPNO'] - df_be['ONIOM_surf_def'] - df_be['mol_def']) * 6.02214076 * 100 * 4.359748199
df_be['BE_e_dlpno_kJmol'] = df_be['BE_e_dlpno_kJmol'] - df_be['BSSE'] * 6.02214076 * 100 * 4.359748199
df_be['Def_dlpno_kJmol'] = - (df_be['BE_dlpno_kJmol'] - df_be['BE_e_dlpno_kJmol'])
df_be = df_be[df_be['BH_dlpno_kJmol'] < 70]
df_be = df_be.sort_values(by=['BH_dlpno_kJmol'])

T = np.zeros(df_be.shape[0],dtype=float)
P = np.zeros(df_be.shape[0],dtype=float)
P_appr = np.zeros(df_be.shape[0],dtype=float)
BH = df_be['BH_dlpno_kJmol'].tolist()
sample = df_be['n_sample'].tolist()

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
step 	= 1
beta 	= 0.5
N_i  	= 1
A	 	= 1e-19
t_fin 	= 300

#### sample parameters ####
h2o_dh		= [50.37,68.49]
h2o_frq		= np.array([1711.76,3737.17,3849.08])
mass_h20 	= 18.02
sim_h20	 	= 2
Ic_h20 	 	= [1.83,1.21,0.62]

T 			= np.arange(10, t_fin, step,dtype=float)
TPD	        = np.zeros(len(T),dtype=float)

f = 0.5

for k,item in enumerate(sample):
	if True:#k==5:
		N 		= np.zeros(len(T),dtype=float)
		dN 		= np.zeros(len(T),dtype=float)
		Rate	= 0#np.zeros(len(T),dtype=float)
		Rate_des= 0
		Rate_dif= 0
		epsilon = 0
		smp 	= str(item)
		path_g = '/Users/tinaccil/Documents/code/ONIOM/ONIOM_H2O/' + smp + '/grain_mol_opt.hess'
		path_c = '/Users/tinaccil/Documents/code/ONIOM/ONIOM_H2O/' + smp + '/cluster_opt.hess'
		freq_g = read_freq(path_g)
		freq_c = read_freq(path_c)
		bh0		= BH[k]
		for i in range(len(T)):
			Pre_exp 	= pre_factor_approx(T[i],mass_h20,A,sim_h20,Ic_h20)
			Pre_exp_dif = KB * T[i] / H
			#bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,bh0)
			Rate_des	= RH_DesRate(T[i],Pre_exp,bh0)
			Rate_dif_to	= 0
			Rate_dif_in	= 0
			for p,item_p in enumerate(sample):
				if p != k:
					if BH[p] < bh0:
						Rate_dif_to += RH_DesRate(T[i],Pre_exp_dif,(bh0-BH[p]) + f * BH[p])
						Rate_dif_in += RH_DesRate(T[i],Pre_exp_dif,BH[p]*f)
					else:
						Rate_dif_to += RH_DesRate(T[i],Pre_exp_dif,bh0*f)
						Rate_dif_in += RH_DesRate(T[i],Pre_exp_dif,(BH[p]-bh0) + f * bh0)
			epsilon		= Rate_des / (Rate_des + Rate_dif_to)
			Rate = Rate_des * epsilon
			#print(epsilon)
			if i == 0:
				N[i]	= N_i - Rate / beta * N_i * step
				dN[i]  = Rate / beta * N_i * step
			else:
				tmp = Rate / beta * N[i-1] * step
				if N[i-1] - tmp <= 0:
					N[i] = 0
				else:
					N[i]	 = N[i-1] - tmp
					dN[i]   = tmp
		TPD = TPD + dN * gaussian(T,100,T[np.where(dN == np.amax(dN))[0]])

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, TPD,color='blue',linewidth=5,label='BH(T)')
#ax.plot(T,gaussian(T,10,T[np.where(dN == np.amax(dN))[0]]))
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [a.u]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

df = pd.DataFrame()
df['T'] = T
df['TPD'] = TPD

with open("/Users/tinaccil/Documents/code/ONIOM/TPD_H2O_distr.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
import pandas as pd
import matplotlib.pyplot as plt

with open("/Users/tinaccil/Documents/code/ONIOM/sample_per_JCP/H2O_370_fit.csv","r") as data:
	df = pd.read_csv(data, delimiter = '\t', index_col=False)

df['ratio'] = df['370_rate_full'] / df['370_rate_kooji']

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(df['T'], df['ratio'],color='blue',linewidth=5,label='BH(T)')
#ax.plot(T,gaussian(T,10,T[np.where(dN == np.amax(dN))[0]]))
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [a.u]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
plt.yscale('log')
#ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

with open("/Users/tinaccil/Documents/code/ONIOM/H2O_370_fit.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from lib_rate import read_freq_gau, pre_factor_approx, pre_factor_full, RH_DesRate, q_vib, pre_factor_full_6n, kooji, read_freq, BH_t

def gaussian(x,sigma,mean,a):
    return a / sigma / np.sqrt(2 * np.pi) * np.exp(-((x - mean)**2 / (2 * sigma**2)))

with open("/Users/tinaccil/Documents/code/ONIOM/ONIOM_H2O_varie/BE_rendundat.csv","r") as data:
	df_be = pd.read_csv(data, delimiter = '\t', index_col=False)

df_be = df_be[df_be['Rendundat'] == False]

df_be['ZPE_kjmol'] = (df_be['ZPE_complex'] - df_be['ZPE_cluster'] - 0.02118242) * 6.02214076 * 100 * 4.359748199
df_be['BE_B973c_kJmol'] = - (df_be['ONIOM_complex_B973c'] - df_be['ONIOM_cluster_B973c'] - (-76.398366805927)) * 6.02214076 * 100 * 4.359748199
df_be['BH_B973c_kJmol'] = df_be['BE_B973c_kJmol'] - df_be['ZPE_kjmol']
df_be['BE_dlpno_kJmol'] = - (df_be['ONIOM_complex_DLPNO'] - df_be['ONIOM_cluster_DLPNO'] - (-76.342142464944)) * 6.02214076 * 100 * 4.359748199
df_be['BE_dlpno_kJmol'] = df_be['BE_dlpno_kJmol'] - df_be['BSSE'] * 6.02214076 * 100 * 4.359748199
df_be['BH_dlpno_kJmol'] = df_be['BE_dlpno_kJmol'] - df_be['ZPE_kjmol']
df_be['BE_e_dlpno_kJmol'] = - (df_be['ONIOM_complex_DLPNO'] - df_be['ONIOM_surf_def'] - df_be['mol_def']) * 6.02214076 * 100 * 4.359748199
df_be['BE_e_dlpno_kJmol'] = df_be['BE_e_dlpno_kJmol'] - df_be['BSSE'] * 6.02214076 * 100 * 4.359748199
df_be['Def_dlpno_kJmol'] = - (df_be['BE_dlpno_kJmol'] - df_be['BE_e_dlpno_kJmol'])
df_be = df_be[df_be['BH_dlpno_kJmol'] < 70]
df_be = df_be.sort_values(by=['BH_dlpno_kJmol'])

T = np.zeros(df_be.shape[0],dtype=float)
P = np.zeros(df_be.shape[0],dtype=float)
P_appr = np.zeros(df_be.shape[0],dtype=float)
BH = df_be['BH_dlpno_kJmol'].tolist()
sample = df_be['n_sample'].tolist()

#### constant ####
KB 			= 1.3806488e-23
H  			= 6.62606957e-34
C 			= 2.99792458e10
R 			= 8.3144621
AV 			= 6.0221415e23
AMUtoKG 	= 1.66053886e-27
CMtokJmol 	= 1.1962659192089765e-2 #C * H * AV change due to numerical errors
CMtoK 		= 1.4387862961655296
kjtokcal 	= 4.184
KJMOLtoK	= 120.2731159571
MHZtoK 		=  6.62606957 / 1.3806488 * 1e-5 # e-34 * 1e6 / e-23
AUconv 		= 1.66053886 * 1.3806488 / 6.62606957 / 6.62606957 * 1e18 # AMUtoKG * KB / H / H
UMAAAtoKGM 	= 1.660539e-47

#### WP equation parameters ####
step 	= 1
beta 	= 0.04
N_i  	= 1
A	 	= 1e-19
t_fin 	= 300

#### sample parameters ####
h2o_dh		= [50.37,68.49]
h2o_frq		= np.array([1711.76,3737.17,3849.08])
mass_h20 	= 18.02
sim_h20	 	= 2
Ic_h20 	 	= [1.83,1.21,0.62]

T 			= np.arange(10, t_fin, step,dtype=float)
TPD	        = np.zeros(len(T),dtype=float)
be 			= np.arange(10, 60, 1,dtype=float)
eps	        = np.zeros((len(T),len(be)),dtype=float)
rt			= np.zeros((len(T),len(be)),dtype=float)
rtf			= np.zeros((len(T),len(be)),dtype=float)
rtdif		= np.zeros((len(T),len(be)),dtype=float)

f = 0.3

#be = [30,40]

for k in range(len(be)):
	N 		= np.zeros(len(T),dtype=float)
	dN 		= np.zeros(len(T),dtype=float)
	Rate	= 0#np.zeros(len(T),dtype=float)
	bh0 	= be[k]
	pbh0	= gaussian(be[k],9.73,35.4,763.76)
	#Rate_des= 0
	#Rate_dif= 0
	#epsilon = 0
	for i in range(len(T)):
		Pre_exp 	= pre_factor_approx(T[i],mass_h20,A,sim_h20,Ic_h20)
		Pre_exp_dif = KB * T[i] / H
		#bh			= BH_t(T[i],h2o_frq,freq_c,freq_g,bh0)
		Rate_des	= RH_DesRate(T[i],Pre_exp,bh0)
		Rate_dif_to	= 0
		Rate_dif_in	= 0
		epsilon 	= 1
		for p,item_p in enumerate(sample):
			if p != k:
				if BH[p] < bh0:
					Rate_dif_to += RH_DesRate(T[i],Pre_exp,(bh0-BH[p]) + f * BH[p])
					Rate_dif_in += RH_DesRate(T[i],Pre_exp,BH[p]*f) * RH_DesRate(T[i],Pre_exp,BH[p])
				else:
					Rate_dif_to += RH_DesRate(T[i],Pre_exp,bh0*f)
					Rate_dif_in += RH_DesRate(T[i],Pre_exp,(BH[p]-bh0) + f * bh0) * RH_DesRate(T[i],Pre_exp,BH[p])
		epsilon		= Rate_des * Rate_dif_to/ (Rate_des * Rate_dif_to + Rate_dif_in)
		eps[i,k] = epsilon
		rt[i,k] = Rate_des
		rtdif[i,k] = Rate_dif_in
		Rate = Rate_des * epsilon
		rtf[i,k] = Rate
		#print(epsilon)/
		if i == 0:
			N[i]	= N_i - Rate / beta * N_i * step + Rate_diff / beta * N_i * step
			dN[i]   = Rate / beta * N_i * step - Rate_diff / beta * N_i * step
		else:
			tmp = Rate / beta * N[i-1] * step
			if N[i-1] - tmp <= 0:
				N[i] = 0
			else:
				N[i]	 = N[i-1] - tmp
				dN[i]   = tmp
	TPD += dN * pbh0

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, TPD,color='blue',linewidth=5,label='BH(T)')
#ax.plot(T,gaussian(T,10,T[np.where(dN == np.amax(dN))[0]]))
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [a.u]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

df = pd.DataFrame()
df['T'] = T
df['TPD'] = TPD

with open("/Users/tinaccil/Documents/code/ONIOM/TPD_H2O_distr.csv","w+") as output:
	output.write(df.to_csv(sep="\t", index=False))

# %%
fig, ax = plt.subplots(2,2,figsize=(15,15))

img = ax[0, 0].imshow(np.log10(eps), cmap=plt.cm.viridis, aspect='auto',extent=[T.min(),T.max()/step,be.min(),be.max()]) # pl is pylab imported a pl
plt.colorbar(img, ax=ax[0, 0])
ax[0, 0].set_title('epsilon', fontsize=15)
ax[0, 0].set_xlabel('T [K]', fontsize=15)
ax[0, 0].set_ylabel('BE [kJ/mol]', fontsize=15)
#plt.show()

img = ax[0, 1].imshow(np.log10(rt), cmap=plt.cm.viridis, aspect='auto',extent=[T.min(),T.max()/step,be.min(),be.max()]) # pl is pylab imported a pl
plt.colorbar(img,ax=ax[0, 1])
ax[0, 1].set_title('rate', fontsize=15)
ax[0, 1].set_xlabel('T [K]', fontsize=15)
ax[0, 1].set_ylabel('BE [kJ/mol]', fontsize=15)
#plt.show()

img = ax[1, 0].imshow(np.log10(rtf), cmap=plt.cm.viridis, aspect='auto',extent=[T.min(),T.max()/step,be.min(),be.max()]) # pl is pylab imported a pl
plt.colorbar(img,ax=ax[1, 0])
ax[1, 0].set_title('rate * epsilon', fontsize=15)
ax[1, 0].set_xlabel('T [K]', fontsize=15)
ax[1, 0].set_ylabel('BE [kJ/mol]', fontsize=15)
#plt.show()

img = ax[1, 1].imshow(np.log10(rtdif), cmap=plt.cm.viridis, aspect='auto',extent=[T.min(),T.max()/step,be.min(),be.max()]) # pl is pylab imported a pl
plt.colorbar(img,ax=ax[1, 1])
ax[1, 1].set_title('rate dif to', fontsize=15)
ax[1, 1].set_xlabel('T [K]', fontsize=15)
ax[1, 1].set_ylabel('BE [kJ/mol]', fontsize=15)

# %%
fig, ax = plt.subplots(figsize=(7,7))
#ax.plot(be, gaussian(be,9.73,35.4,763.76),color='blue',linewidth=5,label='BH(T)')
#ax.plot(T,gaussian(T,10,T[np.where(dN == np.amax(dN))[0]]))
ax.plot(T, TPD,color='blue',linewidth=5,label='BH(T)')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [a.u]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()

print(gaussian(20,35.4,9.73,763.76))

# %%
T    = pd.Series(df['T'].to_numpy(dtype=float))
dN	 = pd.Series(df['TPD'].to_numpy(dtype=float))

with open("/Users/tinaccil/Documents/code/ONIOM/TPD_H2O_distr_BHT.csv","r") as data:
	df_bh = pd.read_csv(data, delimiter = '\t', index_col=False)
dN_b	 = pd.Series(df_bh['TPD'].to_numpy(dtype=float))

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(T, dN,color='red',linewidth=5,label='BH(0)')
ax.plot(T, dN_b,color='blue',linewidth=5,label='BH(T)')
ax.set_xlabel('T [K]', fontsize=15)
ax.set_ylabel('-dN/dT [a.u]', fontsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.xaxis.set_tick_params(labelsize=15)
ax.legend(fontsize=15)
#ax.set_xlim(35,45)
#ax.set_xlim(80,120)
ax.grid()
plt.show()
